# %%
from googleapiclient.discovery import build

# Replace with your API key
api_key = 'AIzaSyAy5zvDfg9AWSOVKYBnU-NkJfVtun5hKH0'

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Replace with the channel ID of the desired channel
channel_id = 'UCjNgqJ_FMLntYVzq7daw1TQ'

# Get the playlist ID for the uploads of the channel
channel_response = youtube.channels().list(
    id=channel_id,
    
    part='contentDetails'
).execute()

uploads_playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# Get the videos from the uploads playlist
playlist_items_response = youtube.playlistItems().list(
    playlistId=uploads_playlist_id,
    part='contentDetails',
    maxResults=50  # Adjust as needed
).execute()

# Extract video URLs from playlist items
video_urls = []
for playlist_item in playlist_items_response.get('items', []):
    video_id = playlist_item['contentDetails']['videoId']
    video_url = f"https://www.youtube.com/watch?v={video_id}"
    video_urls.append(video_url)

# Print the extracted video URLs
for url in video_urls:
    print(url)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1365                 if conn.sock is None:
# -> 1366                     conn.connect()
#    1367                 conn.request(method, request_uri, body, headers)
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in connect(self)
#    1141
# -> 1142         address_info = socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM)
#    1143         for family, socktype, proto, canonname, sockaddr in address_info:
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
# ...

# %%
pip install google-auth google-auth-oauthlib google-auth-httplib2 googleapiclient
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement googleapiclient (from versions: none)
# ERROR: No matching distribution found for googleapiclient

# %%
pip install isodate
# Out:
# ...
#      -------------------------------------- 41.7/41.7 kB 684.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build

# Replace with your API key
api_key = 'AIzaSyCMA7TYcXFacjXbjEdwt55sgBqzUNap28s'

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Replace with the channel ID of the desired channel
channel_id = 'UCO2WJZKQoDW4Te6NHx4KfTg'

# Get the playlist ID for the uploads of the channel
channel_response = youtube.channels().list(
    id=channel_id,
    part='contentDetails'
).execute()

uploads_playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# Get the videos from the uploads playlist
playlist_items_response = youtube.playlistItems().list(
    playlistId=uploads_playlist_id,
    part='contentDetails',
    maxResults=100  # Adjust as needed
).execute()

# Extract video URLs from playlist items
video_urls = []
for playlist_item in playlist_items_response.get('items', []):
    video_id = playlist_item['contentDetails']['videoId']
    video_url = f"https://www.youtube.com/watch?v={video_id}"
    video_urls.append(video_url)

# Print the extracted video URLs
for url in video_urls:
    print(url)
# Out:
# https://www.youtube.com/watch?v=GQD2gWIkLKA
# https://www.youtube.com/watch?v=iENXIdRLRLk
# https://www.youtube.com/watch?v=Re_N-mfiKgc
# https://www.youtube.com/watch?v=iHqcyObncLc
# https://www.youtube.com/watch?v=ckpz0d1wZhI
# https://www.youtube.com/watch?v=UZdGx8Qdrmo
# https://www.youtube.com/watch?v=FZRTPCO7pWw
# https://www.youtube.com/watch?v=DAay0zsbAV4
# https://www.youtube.com/watch?v=VcPOI14hFZM
# https://www.youtube.com/watch?v=a_C8YpwmZXY
# https://www.youtube.com/watch?v=AYU2ZuFD390
# https://www.youtube.com/watch?v=Z_Uru8TJ2Uc
# https://www.youtube.com/watch?v=kig42fLeR_M
# https://www.youtube.com/watch?v=Q3j0nLAnfPI
# https://www.youtube.com/watch?v=IMmhJCiHimY
# https://www.youtube.com/watch?v=Ra8SDOly_Ds
# https://www.youtube.com/watch?v=9piMl6enj3A
# https://www.youtube.com/watch?v=_wW80awlhVk
# https://www.youtube.com/watch?v=l-nl84mwlMk
# https://www.youtube.com/watch?v=qtxqcShMJ24
# https://www.youtube.com/watch?v=W5nZow5vYQw
# ...

# %%
from googleapiclient.discovery import build

# Replace with your API key
api_key = 'AIzaSyCMA7TYcXFacjXbjEdwt55sgBqzUNap28s'

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Replace with the username or URL of the channel
channel_username = 'Geekyranjit'

# Use the search endpoint to find the channel
search_response = youtube.search().list(
    q=channel_username,
    type='channel',
    part='id',
    maxResults=1
).execute()

# Extract channel ID from search results
channel_id = search_response['items'][0]['id']['channelId']
print("Channel ID:", channel_id)
# Out:
# Channel ID: UCO2WJZKQoDW4Te6NHx4KfTg

# %%
import csv
from pytube import YouTube
from googleapiclient.discovery import build


# Read video URLs from the CSV file
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

video_urls = []
with open('D:\mlproject\data3.csv','r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        video_urls.append(row['video url'])
        
video_data = []

# Loop through each video URL and get information
for idx, video_url in enumerate(video_urls, start=1):
    try:
        yt_video = YouTube(video_url)
        # Get video ID from the URL using pytube
        video_id = yt_video.video_id
        
        # Use YouTube Data API to get likes and comments counts
        video_response = youtube.videos().list(
            part='statistics',
            id=video_id
        ).execute()
        
        video_stats = video_response['items'][0]['statistics']
        likes_count = int(video_stats.get('likeCount', 0))
        comments_count = int(video_stats.get('commentCount', 0))
        
        video_data.append({
            'Index': idx,
            'Video Url': video_url,
            'Video Title': yt_video.title,
            'Video Views': yt_video.views,
            'Video Likes': likes_count,
            'Video Comments': comments_count,
            'Video Author': yt_video.author,
            'Duration In Seconds': yt_video.length
        })

    except Exception as e:
        print(f"Error processing {video_url}: {e}")
        print("\n")
        
output_csv_file = 'Youtube_data3.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Index', 'Video Url', 'Video Title', 'Video Views', 'Video Likes', 'Video Comments', 'Video Author', 'Duration In Seconds']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()

    for data in video_data:
        # Encode each field, ignoring problematic characters
        encoded_data = {k: v.encode('utf-8', 'ignore').decode('utf-8') if isinstance(v, str) else v for k, v in data.items()}
        csv_writer.writerow(encoded_data)

print(f"Video data saved to {output_csv_file}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9960\2264464068.py in <module>
#      38             'Index': idx,
#      39             'Video Url': video_url,
# ---> 40             'Video Title': yt_video.title,
#      41             'Video Views': yt_video.views,
#      42             'Video Likes': likes_count,
#
# ~\anaconda3\lib\site-packages\pytube\__main__.py in title(self)
#     339
#     340         try:
# --> 341             self._title = self.vid_info['videoDetails']['title']
#     342         except KeyError:
#     343             # Check_availability will raise the correct exception in most cases
#
# ~\anaconda3\lib\site-packages\pytube\__main__.py in vid_info(self)
#     244         innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
#     245
# ...

# %%
import requests

API_KEY = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'
BASE_URL = 'https://www.googleapis.com/youtube/v3/search'

keyword = 'technology'
max_results = 10  # Number of results you want

params = {
    'key': API_KEY,
    'q': keyword,
    'part': 'snippet',  # Include video metadata
    'maxResults': max_results,
    'type': 'video',    # Search for videos only
}

response = requests.get(BASE_URL, params=params)
data = response.json()

# Extract video URLs from the response
video_urls = []
for item in data['items']:
    video_id = item['id']['videoId']
    video_url = f'https://www.youtube.com/watch?v={video_id}'
    video_urls.append(video_url)

print(video_urls)
# Out:
# ['https://www.youtube.com/watch?v=NrrhpjnSZwE', 'https://www.youtube.com/watch?v=dig9zKdLags', 'https://www.youtube.com/watch?v=mstlDn8MxF8', 'https://www.youtube.com/watch?v=KVLIrWfXO6A', 'https://www.youtube.com/watch?v=E0H6ojmnMHo', 'https://www.youtube.com/watch?v=3g6a5DIm778', 'https://www.youtube.com/watch?v=t-OyxDHELFU', 'https://www.youtube.com/watch?v=bXQdf9Mjn6Q', 'https://www.youtube.com/watch?v=nHFR9eUHdqM', 'https://www.youtube.com/watch?v=-JWJ3ZOLwAo']

# %%
import csv
from googleapiclient.discovery import build

# Replace with your API key
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Define search parameters
search_query = 'skin care'
max_results = 50  # Number of results per page
total_results = 500  # Total number of results to retrieve

# Create a list to store video URLs
video_urls = []

next_page_token = None
while len(video_urls) < total_results:
    search_response = youtube.search().list(
        q=search_query,
        type='video',
        part='id',
        maxResults=max_results,
        pageToken=next_page_token
    ).execute()

    video_ids = [search_result['id']['videoId'] for search_result in search_response.get('items', [])]
    video_urls.extend([f"https://www.youtube.com/watch?v={video_id}" for video_id in video_ids])

    next_page_token = search_response.get('nextPageToken')
    if not next_page_token:
        break  # No more pages available

# Print the extracted video URLs
for url in video_urls:
    print(url)
# Out:
# https://www.youtube.com/watch?v=z82QjQazBY4
# https://www.youtube.com/watch?v=xzO-bMmNLJo
# https://www.youtube.com/watch?v=9la3BjX_EZE
# https://www.youtube.com/watch?v=_7srMTTHVkY
# https://www.youtube.com/watch?v=xnMmJwj39ds
# https://www.youtube.com/watch?v=PLUorDoO1t0
# https://www.youtube.com/watch?v=yXcnNlTtyTk
# https://www.youtube.com/watch?v=5_z7nirvrMw
# https://www.youtube.com/watch?v=n7KPvPyjRJA
# https://www.youtube.com/watch?v=idGV_UvkOSo
# https://www.youtube.com/watch?v=tasgmuECLJs
# https://www.youtube.com/watch?v=5JxzAsjiXc4
# https://www.youtube.com/watch?v=EKNvA4GBmvw
# https://www.youtube.com/watch?v=IksXDY77k9I
# https://www.youtube.com/watch?v=TXH0NbrqqEs
# https://www.youtube.com/watch?v=1vNIIc8GXLc
# https://www.youtube.com/watch?v=tzK724aK-eU
# https://www.youtube.com/watch?v=khhA-FiwuGE
# https://www.youtube.com/watch?v=IYcmRWVmRgg
# https://www.youtube.com/watch?v=-B6UEmXPfVM
# https://www.youtube.com/watch?v=9L-2xYWzCqQ
# ...

# %%
import csv
from googleapiclient.discovery import build
import isodate  # Importing the isodate library to parse video duration

# Replace with your API key
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Define search parameters
search_query = 'gaming'
max_results = 50  # Number of results per page
total_results = 500  # Total number of results to retrieve

# Create a list to store video URLs
video_urls = []

next_page_token = None
while len(video_urls) < total_results:
    search_response = youtube.search().list(
        q=search_query,
        type='video',
        part='id',
        maxResults=max_results,
        pageToken=next_page_token
    ).execute()

    video_ids = [search_result['id']['videoId'] for search_result in search_response.get('items', [])]

    # Fetch video details to check the duration
    video_details = youtube.videos().list(
        part='contentDetails',
        id=','.join(video_ids)
    ).execute()

    for video in video_details.get('items', []):
        video_duration = isodate.parse_duration(video['contentDetails']['duration']).total_seconds()
        if video_duration > 120:  # Filter videos longer than 2 minutes (120 seconds)
            video_urls.append(f"https://www.youtube.com/watch?v={video['id']}")

    next_page_token = search_response.get('nextPageToken')
    if not next_page_token:
        break  # No more pages available

# Print the extracted video URLs
for url in video_urls:
    print(url)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4404\1553004907.py in <module>
#      19 next_page_token = None
#      20 while len(video_urls) < total_results:
# ---> 21     search_response = youtube.search().list(
#      22         q=search_query,
#      23         type='video',
#
# ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# ~\anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# ...

# %%
import csv
from pytube import YouTube
from googleapiclient.discovery import build

# Read video URLs from the CSV file
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

video_urls = []
with open('D:\mlproject\data4.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        video_urls.append(row['video url'])

video_data = []

# Loop through each video URL and get information
for idx, video_url in enumerate(video_urls, start=1):
    try:
        yt_video = YouTube(video_url)
        # Get video ID from the URL using pytube
        video_id = yt_video.video_id
        
        # Use YouTube Data API to get likes and comments counts
        video_response = youtube.videos().list(
            part='statistics',
            id=video_id
        ).execute()
        
        video_stats = video_response['items'][0]['statistics']
        likes_count = int(video_stats.get('likeCount', 0))
        comments_count = int(video_stats.get('commentCount', 0))
        
        # Fetch comments using pytube's get_comments() method
        comments = yt_video.comments
        comment_list = []
        for comment in comments:
            comment_list.append(comment.text)
        
        video_data.append({
            'Index': idx,
            'Video Url': video_url,
            'Video Title': yt_video.title,
            'Video Views': yt_video.views,
            'Video Likes': likes_count,
            'Video Comments': comments_count,
            'Video Author': yt_video.author,
            'Duration In Seconds': yt_video.length,
            'Comments': comment_list  # Add the comments to the dictionary
        })

    except Exception as e:
        print(f"Error processing {video_url}: {e}")
        print("\n")

output_csv_file = 'Youtube_data4.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Index', 'Video Url', 'Video Title', 'Video Views', 'Video Likes', 'Video Comments', 'Video Author', 'Duration In Seconds', 'Comments']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()

    for data in video_data:
        # Encode each field, ignoring problematic characters
        encoded_data = {k: v.encode('utf-8', 'ignore').decode('utf-8') if isinstance(v, str) else v for k, v in data.items()}
        csv_writer.writerow(encoded_data)

print(f"Video data saved to {output_csv_file}")
# Out:
# Error processing https://www.youtube.com/watch?v=EytSHmDICgE: 'YouTube' object has no attribute 'comments'
#
#
# Video data saved to Youtube_data4.csv

# %%
import requests
import json

# Set your YouTube API key
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'

# Set the video ID for which you want to scrape comments
video_id = 'kMiy8ZywF88'

# Make API request to retrieve video comments
url = f'https://www.googleapis.com/youtube/v3/commentThreads?key={api_key}&videoId={video_id}&part=snippet&maxResults=100'
response = requests.get(url)
data = response.json()

# Extract comments
comments = []
for item in data['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    comments.append(comment)

# Save comments to a file
with open('comments.txt', 'w', encoding='utf-8') as f:
    for comment in comments:
        f.write(comment + '\n' + '~')

print('Comments saved to comments1')
# Out:
# Comments saved to comments1

# %%
import requests
import csv

api_key = 'YOUR_API_KEY'  # Replace with your YouTube Data API key

# Read video URLs from CSV and extract video IDs
video_ids = []
with open('video_urls.csv', 'r', newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        url = row[0]
        video_id = url.split('v=')[-1]
        video_ids.append(video_id)

all_comments = []

# Loop through video IDs to extract comments
for video_id in video_ids:
    url = f'https://www.googleapis.com/youtube/v3/commentThreads?key={api_key}&videoId={video_id}&part=snippet&maxResults=100'
    response = requests.get(url)
    data = response.json()

    for item in data['items']:
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
        all_comments.append(comment)

# Save comments to a CSV file
csv_file = 'all_comments.csv'
with open(csv_file, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['Comment'])
    writer.writerows([[comment] for comment in all_comments])

print(f'All comments saved to {csv_file}')

# %%
import csv
from pytube import YouTube
from googleapiclient.discovery import build

# Read video URLs from the CSV file
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'  # Replace with your YouTube Data API key

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

video_urls = []
with open('D:\mlproject\data.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        video_urls.append(row['video url'])

video_data = []

# Loop through each video URL and get information
for idx, video_url in enumerate(video_urls, start=1):
    try:
        yt_video = YouTube(video_url)
        # Get video ID from the URL using pytube
        video_id = yt_video.video_id
        
        # Use YouTube Data API to get likes and comments counts
        video_response = youtube.videos().list(
            part='statistics',
            id=video_id
        ).execute()
        
        video_stats = video_response['items'][0]['statistics']
        likes_count = int(video_stats.get('likeCount', 0))
        comments_count = int(video_stats.get('commentCount', 0))
        
        # Fetch comments using pytube's get_comments() method
        comments = yt_video.comments
        comment_list = []
        for comment in comments:
            comment_list.append(comment.text)
        
        video_data.append({
            'Index': idx,
            'Video Url': video_url,
            'Video Title': yt_video.title,
            'Video Views': yt_video.views,
            'Video Likes': likes_count,
            'Video Comments': comments_count,
            'Video Author': yt_video.author,
            'Duration In Seconds': yt_video.length,
            'Comments': comment_list  # Add the comments to the dictionary
        })

    except Exception as e:
        print(f"Error processing {video_url}: {e}")
        print("\n")

output_csv_file = 'Youtube_data5.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Index', 'Video Url', 'Video Title', 'Video Views', 'Video Likes', 'Video Comments', 'Video Author', 'Duration In Seconds', 'Comments']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()

    for data in video_data:
        # Encode each field, ignoring problematic characters
        encoded_data = {k: v.encode('utf-8', 'ignore').decode('utf-8') if isinstance(v, str) else v for k, v in data.items()}
        csv_writer.writerow(encoded_data)

print(f"Video data saved to {output_csv_file}")
# Out:
# Error processing https://www.youtube.com/watch?v=mIi6EGG7YhE: 'YouTube' object has no attribute 'comments'
#
#
# Error processing https://www.youtube.com/watch?v=hCC-zFwrRRY: 'YouTube' object has no attribute 'comments'
#
#
# Error processing https://www.youtube.com/watch?v=r_y9vk1L7KE: 'YouTube' object has no attribute 'comments'
#
#
# Error processing https://www.youtube.com/watch?v=MeeLwCwGPTE: 'YouTube' object has no attribute 'comments'
#
#
# Error processing https://www.youtube.com/watch?v=M3LH52WurYQ: 'YouTube' object has no attribute 'comments'
#
#
# Error processing https://www.youtube.com/watch?v=N1eHHWBT--I: 'YouTube' object has no attribute 'comments'
#
#
# Error processing https://www.youtube.com/watch?v=F54jX5hOees: 'YouTube' object has no attribute 'comments'
#
#
# Error processing https://www.youtube.com/watch?v=3O7G9v3EDPk: 'YouTube' object has no attribute 'comments'
#
#
# ...

# %%
import csv
from googleapiclient.discovery import build

# Read video URLs from the CSV file
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'  # Replace with your YouTube Data API key

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

video_urls = []
with open('D:\mlproject\data3.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        video_urls.append(row['video url'])

video_data = []

# Loop through each video URL and get information
for idx, video_url in enumerate(video_urls, start=1):
    try:
        # Extract video ID from the URL
        video_id = video_url.split('v=')[-1]
        
        # Use YouTube Data API to get video details
        video_response = youtube.videos().list(
            part='snippet,statistics',
            id=video_id
        ).execute()
        
        video_snippet = video_response['items'][0]['snippet']
        video_stats = video_response['items'][0]['statistics']
        
        # Fetch comments using YouTube Data API
        comments_response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            textFormat='plainText',
            maxResults=100
        ).execute()
        
        comment_list = []
        for comment_item in comments_response['items']:
            comment = comment_item['snippet']['topLevelComment']['snippet']['textDisplay']
            comment_list.append(comment)
        
        video_data.append({
            'Index': idx,
            'Video Url': video_url,
            'Video Title': video_snippet['title'],
            'Video Views': video_stats.get('viewCount', 0),
            'Video Likes': video_stats.get('likeCount', 0),
            'Video Comments': video_stats.get('commentCount', 0),
            'Video Author': video_snippet['channelTitle'],
            'Duration In Seconds': video_stats.get('duration', 0),
            'Comments': comment_list  # Add the comments to the dictionary
        })

    except Exception as e:
        print(f"Error processing {video_url}: {e}")
        print("\n")

output_csv_file = 'Youtube_data_comments.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Index', 'Video Url', 'Video Title', 'Video Views', 'Video Likes', 'Video Comments', 'Video Author', 'Duration In Seconds', 'Comments']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()

    for data in video_data:
        # Encode each field, ignoring problematic characters
        encoded_data = {k: v.encode('utf-8', 'ignore').decode('utf-8') if isinstance(v, str) else v for k, v in data.items()}
        csv_writer.writerow(encoded_data)

print(f"Video data saved to {output_csv_file}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9960\2092326329.py in <module>
#       1 import csv
# ----> 2 from pytube import Youtube
#       3 from googleapiclient.discovery import build
#       4
#       5 # Read video URLs from the CSV file
#
# ImportError: cannot import name 'Youtube' from 'pytube' (C:\Users\arpit\anaconda3\lib\site-packages\pytube\__init__.py)

# %%
pip install --upgrade pytube
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
from googleapiclient.discovery import build

# Read video URLs from the CSV file
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'  # Replace with your YouTube Data API key

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

video_urls = []
with open('D:\mlproject\data3.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        video_urls.append(row['video url'])

video_data = []

# Loop through each video URL and get information
for idx, video_url in enumerate(video_urls, start=1):
    try:
        # Extract video ID from the URL
        video_id = video_url.split('v=')[-1]
        
        # Use YouTube Data API to get video details
        video_response = youtube.videos().list(
            part='snippet,statistics',
            id=video_id
        ).execute()
        
        video_snippet = video_response['items'][0]['snippet']
        video_stats = video_response['items'][0]['statistics']
        
        # Fetch comments using YouTube Data API
        comments_response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            textFormat='plainText',
            maxResults=100
        ).execute()
        
        comment_list = []
        for comment_item in comments_response['items']:
            comment = comment_item['snippet']['topLevelComment']['snippet']['textDisplay']
            comment_list.append(comment)
        
        # Join comments with '//'
        comments_joined = '||'.join(comment_list)

        video_data.append({
            'Index': idx,
            'Video Url': video_url,
            'Video Title': video_snippet['title'],
            'Video Views': video_stats.get('viewCount', 0),
            'Video Likes': video_stats.get('likeCount', 0),
            'Video Comments': video_stats.get('commentCount', 0),
            'Video Author': video_snippet['channelTitle'],
            'Duration In Seconds': video_stats.get('duration', 0),
            'Comments': comments_joined  # Join comments with '||'
        })

    except Exception as e:
        print(f"Error processing {video_url}: {e}")
        print("\n")

output_csv_file = 'final_Comments.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Index', 'Video Url', 'Video Title', 'Video Views', 'Video Likes', 'Video Comments', 'Video Author', 'Duration In Seconds', 'Comments']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()

    for data in video_data:
        # Encode each field, ignoring problematic characters
        encoded_data = {k: v.encode('utf-8', 'ignore').decode('utf-8') if isinstance(v, str) else v for k, v in data.items()}
        csv_writer.writerow(encoded_data)

print(f"Video data saved to {output_csv_file}")
# Out:
# Error processing https://www.youtube.com/watch?v=difvQyWFmxw: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=difvQyWFmxw&textFormat=plainText&maxResults=100&key=AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#
#
# ...

# %%
import csv
import re
from googleapiclient.discovery import build

# Read video URLs from the CSV file
api_key = 'AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk'  # Replace with your YouTube Data API key

# Create a YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

def clean_comments(comment):
    # Remove URLs, special characters, emojis, and other noise
    cleaned_comment = re.sub(r'http\S+', '', comment)  # Remove URLs
    cleaned_comment = re.sub(r'[^\w\s]', '', cleaned_comment)  # Remove special characters
    cleaned_comment = re.sub(r'[^a-zA-Z0-9]', ' ', cleaned_comment)  # Remove non-alphanumeric characters
    cleaned_comment = re.sub(r'(?<=\s)@\w+', '', cleaned_comment)  # Remove mentions
    cleaned_comment = re.sub(r'[^\x00-\x7F]+', '', cleaned_comment)  # Remove non-ASCII characters
    
    # Convert to lowercase and remove extra spaces
    cleaned_comment = cleaned_comment.lower().strip()
    
    return cleaned_comment

video_urls = []
with open('D:\mlproject\data3.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        video_urls.append(row['video url'])

video_data = []

# Loop through each video URL and get information
for idx, video_url in enumerate(video_urls, start=1):
    try:
        # Extract video ID from the URL
        video_id = video_url.split('v=')[-1]
        
        # Use YouTube Data API to get video details
        video_response = youtube.videos().list(
            part='snippet,statistics',
            id=video_id
        ).execute()
        
        video_snippet = video_response['items'][0]['snippet']
        video_stats = video_response['items'][0]['statistics']
        
        # Fetch comments using YouTube Data API
        comment_list = []
        next_page_token = None
        
        while True:
            comments_response = youtube.commentThreads().list(
                part='snippet',
                videoId=video_id,
                textFormat='plainText',
                maxResults=150,
                pageToken=next_page_token
            ).execute()
            
            for comment_item in comments_response['items']:
                comment = comment_item['snippet']['topLevelComment']['snippet']['textDisplay']
                cleaned_comment = clean_comments(comment)
                comment_list.append(cleaned_comment)
                
            next_page_token = comments_response.get('nextPageToken')
            if not next_page_token or len(comment_list) >= 150:
                break  # No more pages available or reached 150 comments
        
        comments_text = ' // '.join(comment_list)  # Use ' // ' as delimiter
        
        video_data.append({
            'Index': idx,
            'Video Url': video_url,
            '': '', 
            'Video Title': video_snippet['title'],
            'Video Views': video_stats.get('viewCount', 0),
            'Video Likes': video_stats.get('likeCount', 0),
            'Video Comments': video_stats.get('commentCount', 0),
            'Video Author': video_snippet['channelTitle'],
            'Comments': comments_text  # Use the concatenated comments_text
        })

    except Exception as e:
        print(f"Error processing {video_url}: {e}")
        print("\n")

output_csv_file = 'clean_comment.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Index', 'Video Url', '', 'Video Title', 'Video Views', 'Video Likes', 'Video Comments', 'Video Author', 'Comments']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()

    for data in video_data:
        # Encode each field, ignoring problematic characters
        encoded_data = {k: v.encode('utf-8', 'ignore').decode('utf-8') if isinstance(v, str) else v for k, v in data.items()}
        csv_writer.writerow(encoded_data)

print(f"Video data saved  with clean commnets")
# Out:
# Error processing https://www.youtube.com/watch?v=difvQyWFmxw: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=difvQyWFmxw&textFormat=plainText&maxResults=150&key=AIzaSyA8Bqd1F0qr_Wou3ub641AstJdA_hdPBdk&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#
#
# ...
